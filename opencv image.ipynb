# %%
from PIL import Image
import matplotlib
import matplotlib.pyplot as plt

# %%
import cv2

# %%
chessboard = cv2.imread('chess.jpg')

# %%
chessboard
# Out:
# array([[[  4,  18,  46],
#         [ 12,  27,  53],
#         [ 31,  45,  68],
#         ...,
#         [ 74, 128, 181],
#         [ 75, 128, 185],
#         [ 72, 124, 184]],
#
#        [[ 18,  32,  61],
#         [ 21,  35,  63],
#         [ 19,  33,  56],
#         ...,
#         [ 74, 128, 181],
#         [ 73, 126, 183],
#         [ 73, 126, 183]],
#
#        [[ 47,  58,  90],
#         [ 37,  48,  78],
#         [ 25,  37,  65],
#         ...,
#         [ 73, 127, 180],
#         [ 73, 127, 182],
#         [ 77, 131, 186]],
#
#        ...,
#
#        [[ 51,  80, 155],
#         [ 37,  66, 141],
#         [ 30,  56, 133],
#         ...,
#         [ 40,  49,  86],
#         [ 27,  36,  74],
#         [ 14,  24,  64]],
#
#        [[ 51,  77, 154],
#         [ 37,  63, 140],
#         [ 28,  53, 133],
#         ...,
#         [ 38,  48,  82],
#         [ 30,  39,  77],
#         [ 25,  36,  74]],
#
#        [[ 50,  75, 155],
#         [ 38,  63, 143],
#         [ 28,  53, 133],
# ...

# %%
plt.imshow(chessboard)
