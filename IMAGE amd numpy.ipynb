# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
pic = Image.open("download.jpg")

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=284x177 at 0x201E3B955E0>

# %%
arr=np.asarray(pic)

# %%
arr.shape
# Out:
# (177, 284, 3)

# %%
arr
# Out:
# array([[[  0, 131, 252],
#         [  0, 131, 252],
#         [  0, 131, 252],
#         ...,
#         [ 65, 157, 255],
#         [ 64, 158, 255],
#         [ 61, 158, 255]],
#
#        [[  0, 132, 253],
#         [  0, 132, 253],
#         [  0, 132, 253],
#         ...,
#         [ 65, 157, 255],
#         [ 64, 158, 255],
#         [ 64, 158, 255]],
#
#        [[  0, 132, 253],
#         [  0, 132, 253],
#         [  0, 132, 253],
#         ...,
#         [ 66, 159, 255],
#         [ 65, 158, 254],
#         [ 64, 158, 254]],
#
#        ...,
#
#        [[ 11,  46,   6],
#         [  7,  42,   2],
#         [  2,  37,   0],
#         ...,
#         [ 19,  54,  14],
#         [ 20,  55,  15],
#         [ 23,  55,  18]],
#
#        [[  0,  33,   0],
#         [  0,  27,   0],
#         [  0,  19,   0],
#         ...,
#         [  0,  25,   0],
#         [  0,  25,   0],
#         [  0,  25,   0]],
#
#        [[ 16,  40,   8],
#         [ 16,  41,   9],
#         [ 16,  43,   8],
# ...

# %%
plt.imshow(arr)

# %%
pic_red = arr.copy()

# %%
pic_red[:, :, 1]=0
pic_red[:, :, 2]=0

# %%
plt.imshow(pic_red)

# %%
pic_a = arr.copy()

# %%
pic_a[:, :, 1]=0

# %%
plt.imshow(pic_a)
