# %%
import numpy as np
import cv2

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
img= Image.open('3.jpg')

# %%
pic = cv2.imread('download.jpg')

# %%
hist = cv2.calcHist([pic],[0],None,[256],[0,256])

# %%
hist,bins = np.histogram(pic.ravel(),256,[0,256])

# %% [markdown]
# # Histogram using matplotlib

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('download.jpg',0)
plt.hist(img.ravel(),256,[0,200]); plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('download.jpg',0)
plt.hist(img.ravel(),256,[0,200]); plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

imgG = cv2.imread('3.jpg',0)
plt.hist(imgG.ravel(),256,[0,300]); plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

imgggg = cv2.imread('downloadd.jpg',0)
plt.hist(img.ravel(),256,[0,200]); plt.show()
